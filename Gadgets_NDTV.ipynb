# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://gadgets.ndtv.com/laptops/laptops-under-50000')

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('div', attrs={'class': 'pd-lst-wrp kpc_lhs_widget'})

# %%
len(results)
# Out:
# 50

# %%
results[0]
# Out:
# <div class="pd-lst-wrp kpc_lhs_widget"> <div class="lst-hdr"> <i>1</i> <h3><a data-full-title="Lenovo IdeaPad 520 Laptop" data-product-category="laptops" href="https://gadgets.ndtv.com/lenovo-ideapad-520-6351" title="Lenovo IdeaPad 520">Lenovo IdeaPad 520</a></h3> </div> <div class="dtl-txt"> <p>The Lenovo IdeaPad 520 is a Windows 10 laptop with a 15.60-inch display. It is powered by an Intel Core i5 processor. Other specifications include 8GB of RAM, and  a 2TB HDD.</p> </div> <div class="clearfix margin_t15 margin_b5"> <div class="pdlst-img-wrp"> <div class="pdimg"> <a href="https://gadgets.ndtv.com/lenovo-ideapad-520-6351" title="Lenovo IdeaPad 520"> <img alt="Laptops Under 50000 In India" class="lazy" data-original="https://i.gadgets360cdn.com/products/laptops/large/1546453886_635_lenovo_ideapad-520.jpg?downsize=260:*&amp;output-quality=80&amp;output-format=jpg" src="https://gadgets.ndtv.com/static/icons/laptop_icon.jpg" title="Lenovo IdeaPad 520"> </img></a> <div class="_vfg"> <a href="https://gadgets.ndtv.com/lenovo-ideapad-520-6351#gallery" title="Lenovo IdeaPad 520 Photo Gallery">
#                                     View Photo Gallery
#                                 </a> </div> </div> <div class="pd-price"> <a href="https://gadgets.ndtv.com/lenovo-ideapad-520-6351"> <span class="rupee">Rs.</span>49,990                            </a> </div> </div> <div class="pdlst-dsc-wrp"> <table cellpadding="0" cellspacing="0"> <tbody> <tr><td colspan="2">Lenovo IdeaPad 520 Specifications</td></tr> <tr> <td>Display size</td> <td>15.60-inch</td> </tr> <tr> <td>Processor</td> <td>Core i5</td> </tr> <tr> <td>RAM</td> <td>8GB</td> </tr> <tr> <td>OS</td> <td>Windows 10</td> </tr> <tr> <td>Hard disk</td> <td>2TB</td> </tr> <tr> <td>SSD</td> <td>No</td> </tr> </tbody> </table> <div class="pd-opt-tbl"> <a class="pd-opt-col" href="https://gadgets.ndtv.com/lenovo-ideapad-520-6351" title="Lenovo IdeaPad 520 Full Specs">Lenovo IdeaPad 520 Full Specs</a> <a class="pd-opt-col" href="lenovo-laptops" title="Other Lenovo Laptops">Other Lenovo Laptops</a> </div> </div> </div> </div>

# %%
for check in results[0].find_all('a'):
    print(check.text[:])
# Out:
# Lenovo IdeaPad 520
#
#
#                                     View Photo Gallery
#
#  Rs.49,990
# Lenovo IdeaPad 520 Full Specs
# Other Lenovo Laptops

# %%
store = []
temp = 0
for check in results[0].find_all('a'):
    if temp == 0:
        store.append(check.text[:])
    elif temp == 3:
        store.append(check.text[:].replace(' ', '').replace('Rs.', ''))
    temp += 1

# %%
store
# Out:
# ['Lenovo IdeaPad 520', '49,990']

# %%
for check in results[0].find_all('td'):
    print(check.text[:])
# Out:
# Lenovo IdeaPad 520 Specifications
# Display size
# 15.60-inch
# Processor
# Core i5
# RAM
# 8GB
# OS
# Windows 10
# Hard disk
# 2TB
# SSD
# No

# %%
store = []
temp = 0
for check in results[0].find_all('td'):
    if temp >= 2 and temp % 2 == 0:
        store.append(check.text[:])
    temp += 1

# %%
store
# Out:
# ['15.60-inch', 'Core i5', '8GB', 'Windows 10', '2TB', 'No']

# %%
records = []
for result in results:
    store1 = []
    temp1 = 0
    for check in result.find_all('a'):
        if temp1 == 0:
            store1.append(check.text[:])
        elif temp1 == 3:
            store1.append(check.text[:].replace(' ', '').replace('Rs.', ''))
        temp1 += 1

    store2 = []
    temp2 = 0
    for check in result.find_all('td'):
        if temp2 >= 2 and temp2 % 2 == 0:
            store2.append(check.text[:])
        temp2 += 1
    
    records.append(store1 + store2)

# %%
records
# Out:
# [['Lenovo IdeaPad 520',
#   '49,990',
#   '15.60-inch',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '2TB',
#   'No'],
#  ['Asus VivoBook S510UN-BQ217T',
#   '49,990',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'Nvidia GeForce MX150',
#   '1.70 kg'],
#  ['HP 15-DA0070TX',
#   '49,279',
#   '15.60-inch',
#   'Core i3',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No'],
#  ['Asus VivoBook E203MA-YS03',
#   'AsusVivoBookE203MA-YS03FullSpecs',
#   '11.60-inch',
#   '1366x768 pixels',
#   'No',
#   'Celeron Dual Core',
#   '4GB',
#   'Windows 10',
#   '0.90 kg'],
#  ['Acer ChromeBook CP311-1H-C5PN',
#   '48,443',
#   '11.60-inch',
#   '1366x768 pixels',
#   'Celeron Dual Core',
#   '4GB',
#   'Chrome OS',
#   '32GB',
#   'No',
#   'Intel HD Graphics 500',
#   '1.25 kg'],
#  ['HP 11-V010NR',
#   '47,850',
#   '11.60-inch',
#   '1366x768 pixels',
#   'Celeron Dual Core',
#   '4GB',
#   'Chrome OS',
#   '16GB',
#   'No',
#   'Intel HD Graphics 400',
#   '1.14 kg'],
#  ['Acer ChromeBook',
#   '47,105',
#   '14.00-inch',
#   '1366x768 pixels',
#   'No',
#   'Celeron Dual Core',
#   '4GB',
#   'Chrome OS',
#   '32GB',
#   'No',
#   'Intel Integrated HD Graphics',
#   '1.44 kg'],
#  ['Lenovo ThinkPad E480',
#   'LenovoThinkPadE480FullSpecs',
#   '14.00-inch',
#   '1920x1080 pixels',
#   'Core i7',
#   '16GB',
#   'Windows 10',
#   '500GB',
#   'No',
#   '1.75 kg'],
#  ['Lenovo ThinkPad E460',
#   '46,800',
#   '14.00-inch',
#   '1366x768 pixels',
#   'Core i5',
#   '4GB',
#   'DOS',
#   '1TB',
#   'No',
#   'AMD Radeon R7 M360',
#   '1.90 kg'],
#  ['Samsung ChromeBook 3',
#   'SamsungChromeBook3FullSpecs',
#   '11.60-inch',
#   '1366x768 pixels',
#   'Celeron Dual Core',
#   '2GB',
#   'Chrome OS',
#   'No',
#   '16GB',
#   '1.15 kg'],
#  ['HP 250-G6 2RC12PA',
#   'HP250-G62RC12PAFullSpecs',
#   '15.60-inch',
#   '1366x768 pixels',
#   'No',
#   'Core i5',
#   '4GB',
#   'DOS',
#   'No',
#   'No'],
#  ['Dell Inspiron 5378',
#   '46,189',
#   '13.30-inch',
#   '1920x1080 pixels',
#   'Yes',
#   'Core i5',
#   '8GB',
#   'Windows 10 Home',
#   'No',
#   'No',
#   'Intel Integrated HD Graphics 520'],
#  ['Dell Inspiron 5578',
#   '45,990',
#   '15.60-inch',
#   'Core i7',
#   '8GB',
#   'Windows 10 Home',
#   '1TB',
#   'No'],
#  ['Dell Inspiron 5000 5370',
#   '44,990',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '4GB',
#   'Windows 10 Home',
#   'No',
#   '128GB',
#   'Intel Integrated HD Graphics 620',
#   '1.40 kg'],
#  ['Smartron T Book Flex T1223',
#   '42,490',
#   '12.50-inch',
#   '2560x1600 pixels',
#   'Yes',
#   'Core m3',
#   '4GB',
#   'Windows 10 Home',
#   'No',
#   '128GB',
#   'Intel Integrated HD Graphics',
#   '1.38 kg'],
#  ['Lenovo Z50',
#   '42,000',
#   '15.60-inch',
#   'No',
#   'APU Quad Core',
#   '2GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'Intel Integrated HD Graphics 4400',
#   '2.40 kg'],
#  ['Xiaomi Mi Notebook 14',
#   'XiaomiMiNotebook14Review',
#   '14.00-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10 Home',
#   '512GB',
#   'Nvidia GeForce MX250',
#   '1.50 kg'],
#  ['MarQ by Flipkart Falkon Aerbook',
#   'MarQbyFlipkartFalkonAerbookFullSpecs',
#   '13.30-inch',
#   '1920x1080 pixels',
#   'Core i5',
#   '8GB',
#   'Windows 7 Home',
#   '256GB',
#   'Intel Integrated UHD Graphics 620',
#   '1.26 kg'],
#  ['Dell 5575',
#   '41,000',
#   '15.60-inch',
#   '1920x1080 pixels',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'AMD Radeon R5',
#   '2.20 kg'],
#  ['Lenovo ThinkPad V330',
#   '40,990',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'Core i5',
#   '8GB',
#   'Windows 10 Professional',
#   '256GB',
#   'No',
#   'Intel HD Graphics 620',
#   '1.80 kg'],
#  ['HP 14s (2020)',
#   'HP14s(2020)FullSpecs',
#   '14.00-inch',
#   '1920x1080 pixels',
#   'Core i3',
#   '4GB',
#   'Windows 10 Home',
#   '1TB',
#   '1.53 kg'],
#  ['Asus VivoBook 14 X412FA-EK295T',
#   'AsusVivoBook14X412FA-EK295TReview',
#   '14.00-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10 Home',
#   '512GB',
#   'Integrated Graphics Processor',
#   '1.50 kg'],
#  ['HP NoteBook 14-DF0010NR',
#   '49,847',
#   '14.00-inch',
#   '226x32.4 pixels',
#   'Pentium Dual Core',
#   '4GB',
#   'Windows 10',
#   'No',
#   '128GB',
#   '1.36 kg'],
#  ['HP 15-DB0076NR',
#   'HP15-DB0076NRFullSpecs',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'Ryzen 3',
#   '8GB',
#   'Windows 10',
#   '500GB',
#   'No',
#   '2.04 kg'],
#  ['Lenovo IdeaPad 330E-15IKB',
#   '49,500',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'DOS',
#   '2TB',
#   'No',
#   'Intel Integrated HD Graphics 620',
#   '2.20 kg'],
#  ['HP 15Q-BU101TU',
#   '49,257',
#   '15.60-inch',
#   '1366x768 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'Intel HD Graphics 620',
#   '1.95 kg'],
#  ['HP ChromeBook 14',
#   'HPChromeBook14FullSpecs',
#   '14.00-inch',
#   '1366x768 pixels',
#   'Celeron Dual Core',
#   '4GB',
#   'Chrome OS',
#   'No',
#   '16GB',
#   '2.16 kg'],
#  ['Asus VivoBook F441BA-DS95',
#   'AsusVivoBookF441BA-DS95FullSpecs',
#   '14.00-inch',
#   '1920x1080 pixels',
#   '8GB',
#   'Windows 10',
#   'No',
#   '256GB',
#   'AMD Radeon R5',
#   '1.77 kg'],
#  ['Lenovo IdeaPad N3540',
#   'LenovoIdeaPadN3540FullSpecs',
#   '15.60-inch',
#   '1366x768 pixels',
#   'Pentium Dual Core',
#   '4GB',
#   'Windows 10',
#   '500GB',
#   'No',
#   'Intel HD Graphics'],
#  ['HP 15Q-DS0010TU',
#   '49,990',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'Intel Integrated UHD Graphics 620',
#   '1.77 kg'],
#  ['Microsoft Surface Pro M1796-KJR-00015',
#   'MicrosoftSurfaceProM1796-KJR-00015FullSpecs',
#   '12.50-inch',
#   '2736x1824 pixels',
#   'Yes',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   'No',
#   '128GB',
#   'Intel Integrated HD Graphics'],
#  ['Asus VivoBook R558UQ-DM701D',
#   'AsusVivoBookR558UQ-DM701DFullSpecs',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i7',
#   '8GB',
#   'DOS',
#   '1TB',
#   'No',
#   'Nvidia GeForce 940MX',
#   '2.20 kg'],
#  ['Asus VivoBook R558UQ-DM1106D',
#   'AsusVivoBookR558UQ-DM1106DFullSpecs',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i7',
#   '8GB',
#   'DOS',
#   '1TB',
#   'No',
#   'Nvidia GeForce 940MX',
#   '2.20 kg'],
#  ['MSI PE62-7RE-2024XIN',
#   '49,990',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'Core i7',
#   '8GB',
#   'DOS',
#   '1TB',
#   'No',
#   '2.20 kg'],
#  ['HP 15-AB030TX',
#   '50,000',
#   '15.60-inch',
#   'Core i5',
#   '8GB',
#   'Windows 8',
#   '1TB',
#   'No'],
#  ['Dell Vostro 2420',
#   '50,000',
#   '14.00-inch',
#   'No',
#   'Core i3',
#   '2GB',
#   'Linux',
#   '500GB',
#   'No',
#   'Intel Integrated HD Graphics',
#   '2.19 kg'],
#  ['Lenovo IdeaPad U510 59-389403',
#   'LenovoIdeaPadU51059-389403FullSpecs',
#   'Core i5',
#   '4GB',
#   'Windows 8',
#   '1TB',
#   'No'],
#  ['Acer Aspire X349-M',
#   '49,449',
#   '14.00-inch',
#   '1366x768 pixels',
#   'No',
#   'Core i3',
#   '4GB',
#   'Windows 10 Home',
#   'No',
#   '128GB',
#   'Intel Integrated HD Graphics 520',
#   '1.56 kg'],
#  ['Dell Latitude E5250',
#   '49,900',
#   '12.50-inch',
#   '1366x768 pixels',
#   'No',
#   'Core i3',
#   '4GB',
#   'Windows 10',
#   '256GB',
#   'No',
#   'Intel Integrated HD Graphics',
#   '2.00 kg'],
#  ['Asus S551LB-CJ289H',
#   'AsusS551LB-CJ289HFullSpecs',
#   '15.60-inch',
#   '1366x768 pixels',
#   'Core i5',
#   '4GB',
#   'Windows 8.1',
#   '1TB',
#   'No',
#   'AMD Radeon R2',
#   '2.40 kg'],
#  ['HP Pavilion 15-AU639TX',
#   '49,700',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'Core i7',
#   '4GB',
#   'Linux',
#   'No',
#   'No'],
#  ['Lenovo IdeaPad N405',
#   'LenovoIdeaPadN405FullSpecs',
#   '14.00-inch',
#   '1366x768 pixels',
#   'No',
#   '4GB',
#   'Windows 8',
#   '500GB',
#   'No',
#   '1.60 kg'],
#  ['HP 15-BR105TX',
#   'HP15-BR105TXFullSpecs',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'AMD Radeon 520 Graphics'],
#  ['Dell Latitude E5470',
#   'DellLatitudeE5470FullSpecs',
#   '14.00-inch',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   'No',
#   '128GB',
#   'Intel HD Graphics',
#   '1.76 kg'],
#  ['HP 15G-BR104TX',
#   '49,490',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'AMD Radeon 520 Graphics',
#   '2.10 kg'],
#  ['HP ProBook X360 11-G1-EE',
#   'HPProBookX36011-G1-EEFullSpecs',
#   '11.60-inch',
#   '1366x768 pixels',
#   'Yes',
#   'Celeron Dual Core',
#   '4GB',
#   'Windows 10 Professional',
#   '256GB',
#   'No',
#   'Intel Integrated HD Graphics',
#   '1.44 kg'],
#  ['HP Pavilion 15-AU007TX',
#   '49,990',
#   '15.60-inch',
#   '1366x768 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'Windows 10',
#   '1TB',
#   'No',
#   'Nvidia GeForce 940MX'],
#  ['Dell Latitude 5580',
#   '50,000',
#   '15.60-inch',
#   'Core i5',
#   '8GB',
#   'Windows 10 Professional',
#   'No',
#   '512GB',
#   '3.08 kg'],
#  ['Asus R541UJ-DM265',
#   '50,000',
#   '15.60-inch',
#   '1920x1080 pixels',
#   'No',
#   'Core i5',
#   '8GB',
#   'DOS',
#   'No',
#   'No',
#   'Nvidia',
#   '1.90 kg'],
#  ['Lenovo N22',
#   'LenovoN22FullSpecs',
#   '11.60-inch',
#   'Celeron Dual Core',
#   '4GB',
#   'Windows 10',
#   'No',
#   '64GB',
#   'Intel Integrated Graphics',
#   '1.27 kg']]
